# %% [markdown]
# # Tips

# %% [markdown]
# ### Introduction:
#
# This exercise was created based on the tutorial and documentation from [Seaborn](https://stanford.edu/~mwaskom/software/seaborn/index.html)
# The dataset being used is tips from Seaborn.
#
# ### Step 1. Import the necessary libraries:

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("white")
matplotlib.rcParams['figure.figsize'] = (10.0, 6.0)

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/Visualization/Tips/tips.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called tips

# %%
tips = pd.read_csv("tips.csv", sep=",")
tips.head()
# Out:
#    Unnamed: 0  total_bill   tip     sex smoker  day    time  size
# 0           0       16.99  1.01  Female     No  Sun  Dinner     2
# 1           1       10.34  1.66    Male     No  Sun  Dinner     3
# 2           2       21.01  3.50    Male     No  Sun  Dinner     3
# 3           3       23.68  3.31    Male     No  Sun  Dinner     2
# 4           4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Step 4. Delete the Unnamed 0 column

# %%
del tips["Unnamed: 0"]
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Step 5. Plot the total_bill column histogram

# %%
tips.total_bill.hist()
plt.xlabel("Total bill")
plt.ylabel("Number of bills");

# %%
sns.distplot(tips.total_bill);

# %% [markdown]
# ### Step 6. Create a scatter plot presenting the relationship between total_bill and tip

# %%
plt.scatter(x=tips.tip, y=tips.total_bill)
plt.xlabel("Tip")
plt.ylabel("Total bill");

# %%
sns.regplot(x=tips.tip, y=tips.total_bill);

# %%
sns.jointplot(x=tips.tip, y=tips.total_bill);

# %% [markdown]
# ### Step 7.  Create one image with the relationship of total_bill, tip and size.
# #### Hint: It is just one function.

# %%
sns.pairplot(tips[["total_bill","tip","size"]]);

# %% [markdown]
# ### Step 8. Present the realationship between days and total_bill value

# %%
tips.day.unique()
days_abbr = {"Mon":1, "Tue":2, "Wed":3, "Thur":4, "Fri":5, "Sat":6, "Sun":7}
days_abbr.values()
days_abbr.keys()
tips["days_number"] = tips.day.apply(lambda x: days_abbr[x])
tips.sample(10)
sns.regplot(x=tips.days_number, y=tips.total_bill);

# %%
sns.stripplot(x=tips.day, y=tips.total_bill, jitter=True);

# %% [markdown]
# ### Step 9. Create a scatter plot with the day as the y-axis and tip as the x-axis, differ the dots by sex

# %%
sns.stripplot(x=tips.day, y=tips.total_bill, hue=tips.sex, jitter=True);

# %% [markdown]
# ### Step 10.  Create a box plot presenting the total_bill per day differetiation the time (Dinner or Lunch)

# %%
sns.boxplot(x=tips.total_bill, y=tips.day, hue=tips.time);

# %% [markdown]
# ### Step 11. Create two histograms of the tip value based for Dinner and Lunch. They must be side by side.

# %%
sns.FacetGrid(tips, col="time", size=5).map(plt.hist, "tip");

# %% [markdown]
# ### Step 12. Create two scatterplots graphs, one for Male and another for Female, presenting the total_bill value and tip relationship, differing by smoker or no smoker
# ### They must be side by side.

# %%
sns.FacetGrid(tips, col="sex", hue="smoker", size=6).map(plt.scatter, "total_bill", "tip");
